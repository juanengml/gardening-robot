# %% [markdown]
# # Gardening-robot

# %% [markdown]
# ## Criando um Robô Jardineiro

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv('plantacao.csv')

# %%
df.columns
# Out:
# Index([u'ID', u' MES', u' DIA', u' Hora', u' umidade '], dtype='object')

# %%
df
# Out:
#       ID   MES   DIA   Hora   umidade
# 0      1     1     6     18         17
# 1      1     1    10     12         19
# 2      1     1    19      5          8
# 3      1     1    23      9         12
# 4      1     1     4     16         13
# 5      1     1     2      2          5
# 6      1     1    22     14         15
# 7      1     1    20     14         18
# 8      1     1    23     14         24
# 9      1     1    22     20          1
# 10     1     1     6      2          8
# 11     1     1    12      1         15
# 12     1     1    18      1         11
# 13     1     1    15     22          2
# 14     1     1    12     12         12
# 15     1     1    14      8         12
# 16     1     1     3     23          7
# 17     1     1     1     22         22
# 18     1     1    10      5         17
# 19     1     1    15     14          7
# 20     1     1    10     11         20
# 21     1     1    16      9         16
# 22     1     1    18     22         16
# 23     1     1    15      3         21
# 24     1     1     7     23          0
# 25     1     1     5     23          8
# 26     1     1    11     13         10
# 27     1     1     2     14         12
# 28     1     1    14     14         18
# 29     1     1    17     19         16
# ...   ..   ...   ...    ...        ...
# 1552   4     1    16     12         85
# 1553   4     1     4     14         89
# 1554   4     1     1     18         89
# 1555   4     1     8     23         95
# 1556   4     1     6     17         83
# 1557   4     1     1     23         87
# 1558   4     1     5     16         98
# 1559   4     1     2      1         85
# 1560   4     1    16     23         78
# 1561   4     1    23      6         75
# 1562   4     1    14      0         82
# 1563   4     1    12     21         91
# 1564   4     1    18     23         93
# 1565   4     1     8      5         83
# 1566   4     1     0     11         94
# 1567   4     1     1     18         99
# 1568   4     1    10      5         84
# 1569   4     1     6     10         76
# 1570   4     1    21     13         99
# 1571   4     1     4      3         88
# 1572   4     1     9     11         82
# 1573   4     1    14      6         81
# 1574   4     1    21     20         78
# 1575   4     1     4      3         81
# 1576   4     1     6     13         86
# 1577   4     1     1      1         79
# 1578   4     1    22     19         79
# 1579   4     1    15      2         96
# 1580   4     1    17     18         93
# 1581   4     1    18     15         89
#
# [1582 rows x 5 columns]

# %%
df.describe()
# Out:
#                 ID     MES          DIA         Hora     umidade
# count  1582.000000  1582.0  1582.000000  1582.000000  1582.000000
# mean      2.893173     1.0    11.249052    11.402023    59.176991
# std       1.052976     0.0     6.926097     7.038716    26.994909
# min       1.000000     1.0     0.000000     0.000000     0.000000
# 25%       2.000000     1.0     5.000000     5.000000    40.000000
# 50%       3.000000     1.0    11.000000    12.000000    64.000000
# 75%       4.000000     1.0    17.000000    18.000000    82.000000
# max       4.000000     1.0    23.000000    23.000000    99.000000

# %%
sb.pairplot(df, hue='ID')

# %%
print df.drop('ID',axis = 1)
X = np.array(df.drop('ID',axis = 1))
X
# Out:
#        MES   DIA   Hora   umidade
# 0        1     6     18         17
# 1        1    10     12         19
# 2        1    19      5          8
# 3        1    23      9         12
# 4        1     4     16         13
# 5        1     2      2          5
# 6        1    22     14         15
# 7        1    20     14         18
# 8        1    23     14         24
# 9        1    22     20          1
# 10       1     6      2          8
# 11       1    12      1         15
# 12       1    18      1         11
# 13       1    15     22          2
# 14       1    12     12         12
# 15       1    14      8         12
# 16       1     3     23          7
# 17       1     1     22         22
# 18       1    10      5         17
# 19       1    15     14          7
# 20       1    10     11         20
# 21       1    16      9         16
# 22       1    18     22         16
# 23       1    15      3         21
# 24       1     7     23          0
# 25       1     5     23          8
# 26       1    11     13         10
# 27       1     2     14         12
# 28       1    14     14         18
# 29       1    17     19         16
# ...    ...   ...    ...        ...
# 1552     1    16     12         85
# 1553     1     4     14         89
# 1554     1     1     18         89
# 1555     1     8     23         95
# 1556     1     6     17         83
# 1557     1     1     23         87
# 1558     1     5     16         98
# 1559     1     2      1         85
# 1560     1    16     23         78
# 1561     1    23      6         75
# 1562     1    14      0         82
# 1563     1    12     21         91
# 1564     1    18     23         93
# 1565     1     8      5         83
# 1566     1     0     11         94
# 1567     1     1     18         99
# 1568     1    10      5         84
# 1569     1     6     10         76
# 1570     1    21     13         99
# 1571     1     4      3         88
# 1572     1     9     11         82
# 1573     1    14      6         81
# 1574     1    21     20         78
# 1575     1     4      3         81
# 1576     1     6     13         86
# 1577     1     1      1         79
# 1578     1    22     19         79
# 1579     1    15      2         96
# 1580     1    17     18         93
# 1581     1    18     15         89
#
# [1582 rows x 4 columns]
# array([[ 1,  6, 18, 17],
#        [ 1, 10, 12, 19],
#        [ 1, 19,  5,  8],
#        ...,
#        [ 1, 15,  2, 96],
#        [ 1, 17, 18, 93],
#        [ 1, 18, 15, 89]])

# %%
y = np.array(df["ID"])
y
# Out:
# array([1, 1, 1, ..., 4, 4, 4])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
print X
print y
knn.fit(X,y)
# Out:
# [[ 1  6 18 17]
#  [ 1 10 12 19]
#  [ 1 19  5  8]
#  ...
#  [ 1 15  2 96]
#  [ 1 17 18 93]
#  [ 1 18 15 89]]
# [1 1 1 ... 4 4 4]
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform')

# %%
knn.predict([[ 1, 3, 21, 53 ]])
# Out:
# array([3])
