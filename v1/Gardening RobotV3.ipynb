# %% [markdown]
# # Gardening-robot

# %% [markdown]
# ## Criando um Robô Jardineiro

# %%
from IPython.display import Image
Image("p.png")

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Explorando dados

# %%
df = pd.read_csv('plantacao.csv')

# %%
df.columns
# Out:
# Index([u'ID', u' MES', u' DIA', u' Hora', u' umidade '], dtype='object')

# %%
print "Total de amostras coletados do dataset: ",len(df)
# Out:
# Total de amostras coletados do dataset:  5403

# %% [markdown]
# ### Pre-processando dados

# %%
df.describe()
# Out:
#                 ID          MES          DIA         Hora     umidade
# count  5403.000000  5403.000000  5403.000000  5403.000000  5403.000000
# mean      2.931890     5.514344    20.991116    11.572090    60.335739
# std       0.990788     0.499840     1.396667     7.030724    25.768100
# min       1.000000     5.000000    19.000000     0.000000     0.000000
# 25%       2.000000     5.000000    20.000000     5.000000    47.000000
# 50%       3.000000     6.000000    21.000000    12.000000    64.000000
# 75%       4.000000     6.000000    22.000000    18.000000    81.000000
# max       4.000000     6.000000    23.000000    23.000000    99.000000

# %%
#sb.pairplot(df, hue='ID')
sb.pairplot(df)

# %%
umidade = df[df.columns[4:]] 
umidade.plot()
#fig.savefig('output.png')

# %%
plot = umidade.plot()
fig = plot.get_figure()
fig.savefig("output.png")

# %%
sns.set_style("darkgrid")
fig, ax = plt.subplots()

fig.set_size_inches(15, 8.27)
sns.pointplot(x=" umidade ", y=" MES",data=df, join=True, capsize=0, size=0, aspect=0)

# %% [markdown]
# ## Criando Variavel de Treino

# %%
#print df.drop('ID',axis = 1)
X = np.array(df.drop('ID',axis = 1))

# %% [markdown]
# ## Criando Variavel de Test

# %%
y = np.array(df["ID"])
type(y)
type(df["ID"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Usando Keras para Geração do Modelo

# %%
# !pip install keras==2.2.4
# Out:
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#     100% |████████████████████████████████| 317kB 1.0MB/s ta 0:00:01
# Collecting keras-applications>=1.0.6 (from keras==2.2.4)
#   Downloading https://files.pythonhosted.org/packages/21/56/4bcec5a8d9503a87e58e814c4e32ac2b32c37c685672c30bc8c54c6e478a/Keras_Applications-1.0.8.tar.gz (289kB)
#     100% |████████████████████████████████| 296kB 928kB/s ta 0:00:01
# Collecting numpy>=1.9.1 (from keras==2.2.4)
#   Using cached https://files.pythonhosted.org/packages/1f/c7/198496417c9c2f6226616cff7dedf2115a4f4d0276613bab842ec8ac1e23/numpy-1.16.4-cp27-cp27mu-manylinux1_x86_64.whl
# Collecting keras-preprocessing>=1.0.5 (from keras==2.2.4)
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#     100% |████████████████████████████████| 51kB 2.4MB/s ta 0:00:01
# Collecting scipy>=0.14 (from keras==2.2.4)
#   Using cached https://files.pythonhosted.org/packages/1d/f6/7c16d60aeb3694e5611976cb4f1eaf1c6b7f1e7c55771d691013405a02ea/scipy-1.2.2-cp27-cp27mu-manylinux1_x86_64.whl
# Collecting h5py (from keras==2.2.4)
#   Downloading https://files.pythonhosted.org/packages/53/08/27e4e9a369321862ffdce80ff1770553e9daec65d98befb2e14e7478b698/h5py-2.9.0-cp27-cp27mu-manylinux1_x86_64.whl (2.8MB)
#     100% |████████████████████████████████| 2.8MB 197kB/s ta 0:00:01
# Collecting pyyaml (from keras==2.2.4)
#   Downloading https://files.pythonhosted.org/packages/a3/65/837fefac7475963d1eccf4aa684c23b95aa6c1d033a2c5965ccb11e22623/PyYAML-5.1.1.tar.gz (274kB)
#     100% |████████████████████████████████| 276kB 1.8MB/s ta 0:00:01
# Collecting six>=1.9.0 (from keras==2.2.4)
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Building wheels for collected packages: keras-applications, pyyaml
#   Running setup.py bdist_wheel for keras-applications ... done
#   Stored in directory: /home/painel/.cache/pip/wheels/dd/f2/5d/2689b5547f32c4e258c3b7ccbe7f1d0f2afbb84fb01e830792
#   Running setup.py bdist_wheel for pyyaml ... done
#   Stored in directory: /home/painel/.cache/pip/wheels/16/27/a1/775c62ddea7bfa62324fd1f65847ed31c55dadb6051481ba3f
# Successfully built keras-applications pyyaml
# Installing collected packages: numpy, six, h5py, keras-applications, keras-preprocessing, scipy, pyyaml, keras
# Successfully installed h5py-2.9.0 keras-2.2.4 keras-applications-1.0.8 keras-preprocessing-1.1.0 numpy-1.16.4 pyyaml-5.1.1 scipy-1.2.2 six-1.12.0

# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
x = y
y_ = X
print x
# Out:
# [1 1 1 ... 4 4 4]

# %%
print y_
# Out:
# [[ 6 21 11  8]
#  [ 5 22  3  3]
#  [ 6 22 22 11]
#  ...
#  [ 6 20 20 92]
#  [ 5 23 15 86]
#  [ 5 23 23 85]]

# %%
# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2ad34b605f7b> in <module>()
#       1 # One Hot encode the class labels
# ----> 2 encoder = OneHotEncoder(sparse=False)
#       3 y = encoder.fit_transform(y_)
#       4 #print(y)
#       5
#
# NameError: name 'OneHotEncoder' is not defined
